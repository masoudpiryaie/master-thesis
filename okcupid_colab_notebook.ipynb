# %% [markdown]
# # OkCupid Colab Starter Notebook
# Upload the zip and the CSV, then run these cells.

# %%
# !unzip -o /content/okcupid_colab_package.zip -d /content/

# %%
# !pip install -r /content/okcupid_colab_package/requirements.txt

# %%
# !python /content/okcupid_colab_package/run_experiments.py --csv_path /content/okcupid_profiles.csv --max_users 2000 --candidate_top_n 50
